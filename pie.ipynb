# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:/Users/venkat/Desktop/CSE/IDS/Project/dataset.csv")

c=[2007,1999,1997,2012,2001,1991,2011]
s=["Brazil","India","Japan","Turkey","China","United Kingdom","Ireland"]
plt.pie(c,labels=s,autopct='%.1f%%')
plt.show()
