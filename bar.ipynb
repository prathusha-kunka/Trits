# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:/Users/venkat/Desktop/CSE/IDS/Project/dataset.csv")
''''country=list(df['Calendar Year'])

c=list(df['Donor Name'])
#print(set(c))

l=[]
c1=0
c2=0
c3=0
c4=0
for i in range(0,len(country)):
    if(c[i]=='Brazil' and c1<1):
        l.append(i)
        c1=1

    if(c[i]=='India' and c2<1):
        l.append(i)
        c2=1
        
    if(c[i]=='Japan' and c3<1):
        l.append(i)
        c3=1

    if(c[i]=='China' and c4<1):
        l.append(i)
        c4=1

#print(l)

amountindex=[]
c_I=0
c_J=0
c_B=0
c_C=0
for i in range(0,len(c)):
    if(c[i]=='Brazil' and c_B<1):
        amountindex.append(c[i])
        c_B=1

    if(c[i]=='India' and c_I<1):
        amountindex.append(c[i])
        c_I=1
        
    if(c[i]=='Japan' and c_J<1):
        amountindex.append(c[i])
        c_J=1

    if(c[i]=='China' and c_C<1):
        amountindex.append(c[i])
        c_C=1

#print(amountindex)

plt.ylabel('Donor Name')
plt.xlabel('Calendar Year')
plt.bar(l,amountindex,color="brown")
plt.title('Countries')
df.plot.hist()'''
plt.bar(df['Calendar Year'],df['Donor Name'])
plt.ylabel('Donor Name')
plt.xlabel('Calendar Year')
plt.title('Countries')
plt.show()
