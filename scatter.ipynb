# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
o=pd.read_excel("C:/Users/venkat/Desktop/CSE/IDS/Project/dataset.xlsx",0)
o.head(3155)
o.info()
r=range(0,len(o))
plt.scatter(o['Amount in USD'],o['Calendar Year'])
plt.ylabel('Calendar Year')
plt.xlabel('Receipt Amount')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 13 columns):
# As of Date            599 non-null object
# Fund Name             599 non-null object
# Donor Name            599 non-null object
# Donor Country Code    599 non-null object
# Receipt Type          599 non-null object
# Receipt Quarter       599 non-null object
# Calendar Year         599 non-null int64
# Receipt Currency      599 non-null object
# Receipt Amount        599 non-null float64
# Contribution Type     599 non-null object
# Sub Account           599 non-null object
# Amount in USD         599 non-null float64
# Sector/Theme          599 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 60.9+ KB
# Text(0.5,0,'Receipt Amount')

# %%
# Out:
# (749, 13)

# %%
# Out:
# Text(0.5,0,'Receipt Amount')
